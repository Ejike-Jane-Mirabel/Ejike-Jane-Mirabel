# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('RealGDP20122023.csv')
df.head()
# Out:
#        tyear   Period  Agriculture  CropProduction  Livestock  Forestry  \
# 1981  Annual  2364.37      1854.76          341.41      77.90     90.30
# 1982  Annual  2425.96      1897.08          361.12      73.91     93.86
# 1983  Annual  2409.08      1842.70          393.13      75.28     97.96
# 1984  Annual  2303.51      1759.12          399.69      76.69     68.01
# 1985  Annual  2731.06      2180.91          428.10      78.08     43.97
#
#        Fishing  Industry  MiningAndQuarrying  CrudePetroleumAndNaturalGas  \
# 1981  11753.40   5044.55             4977.42                        21.33
# 1982  10189.10   4507.93             4453.09                        10.29
# 1983   8255.76   4096.99             4052.98                         9.73
# 1984   8392.25   4602.27             4559.20                        14.03
# 1985   8768.30   4962.81             4918.27                        26.19
#
#       ...  RealEstate  ProfessionalScientificAndTechnicalServices  \
# ...

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    index   tyear   Period  Agriculture  CropProduction  Livestock  Forestry  \
# 0   1981  Annual  2364.37      1854.76          341.41      77.90     90.30
# 1   1982  Annual  2425.96      1897.08          361.12      73.91     93.86
# 2   1983  Annual  2409.08      1842.70          393.13      75.28     97.96
# 3   1984  Annual  2303.51      1759.12          399.69      76.69     68.01
# 4   1985  Annual  2731.06      2180.91          428.10      78.08     43.97
#
#     Fishing  Industry  MiningAndQuarrying  ...  RealEstate  \
# 0  11753.40   5044.55             4977.42  ...      421.38
# 1  10189.10   4507.93             4453.09  ...      423.67
# 2   8255.76   4096.99             4052.98  ...      481.17
# 3   8392.25   4602.27             4559.20  ...      518.36
# 4   8768.30   4962.81             4918.27  ...      602.46
#
#    ProfessionalScientificAndTechnicalServices  \
# 0                                        3.23
# 1                                        3.25
# ...

# %%
df.rename({'index':'Year', 'tyear':'Period', 'Period':'Agriculture', 'Agriculture':'CropProduction', 'CropProduction':'Livestock',
       'Livestock':'Forestry', 'Forestry':'Fishing', 'Fishing':'Industry', 'Industry':'MininingQua', 'MiningAndQuarrying':'CrudeOil',
       'CrudePetroleumAndNaturalGas':'CoalMining', 'CoalMining':'MetalOres', 'MetalOres':'Minerals',
       'QuarryingAndOtherMinerals':'Manufacturing','Manufacturing':'OilRefining', 'OilRefining':'Cement', 'Cement':'FoodBev',
       'FoodBeverageAndTobacco':'Textile', 'TextileApparelAndFootwear':'WoodProduct',
       'WoodAndWoodProducts':'PaperProduct', 'PulpPaperAndPaperProducts':'PhamaProduct',
       'ChemicalAndPharmaceuticalProducts':'NonMetalPrd', 'NonMetallicProducts':'PlasticProduct',
       'PlasticAndRubberProducts':'EEE', 'ElectricalAndElectronics':'IronSteel',
       'BasicMetalIronAndSteel':'VehiclesASS', 'MotorVehiclesAndAssembly':'OtherManu',
       'OtherManufacturing':'Gasstem', 'ElectricityGasSteamAndAirCon':'Watersupply',
       'WaterSupplySewageWaste':'Construction', 'Construction':'Services', 'Services':'Trade', 'Trade':'Accommodation',
       'AccommodationAndFoodServices':'Transport', 'TransportationAndStorage':'RoadTransport',
       'RoadTransport':'Rail', 'RailTransportAndPipelines':'WaterTransport', 'WaterTransport':'AirTransport',
       'AirTransport':'TransService', 'TransportServices':'PostServices', 'PostAndCourierServices':'ICT',
       'InformationAndCommunication':'Publishing', 'Publishing':'MusicProduction',
       'MotionPicturesSoundRecordingAndMusicProduction':'Broadcasting', 'Broadcasting':'Entertainment',
       'ArtsEntertainmentAndRecreation':'FinInsurance', 'FinanceAndInsurance':'FinInstitution',
       'FinancialInstitutions':'Insurance', 'Insurance':'RealEstate', 'RealEstate':'SciTech',
       'ProfessionalScientificAndTechnicalServices':'Adminstration',
       'AdministrativeAndSupportServicesBusinessServices':'PublicAdminstration',
       'PublicAdministration':'Education', 'Education':'HealthService', 'HumanHealthAndSocialServices':'OtherService',
       'OtherServices':'GDP2010', 'GDP at 2010 Constant Basic Prices':'Nettaxs',
       'NetTaxesOnProducts':'GDP20102', 'GDP at 2010 Constant Market Prices':'NILL'},axis = 1,inplace =True)
df.head()
# Out:
#    Year  Period  Agriculture  CropProduction  Livestock  Forestry  Fishing  \
# 0  1981  Annual      2364.37         1854.76     341.41     77.90    90.30
# 1  1982  Annual      2425.96         1897.08     361.12     73.91    93.86
# 2  1983  Annual      2409.08         1842.70     393.13     75.28    97.96
# 3  1984  Annual      2303.51         1759.12     399.69     76.69    68.01
# 4  1985  Annual      2731.06         2180.91     428.10     78.08    43.97
#
#    Industry  MininingQua  CrudeOil  ...  SciTech  Adminstration  \
# 0  11753.40      5044.55   4977.42  ...   421.38           3.23
# 1  10189.10      4507.93   4453.09  ...   423.67           3.25
# 2   8255.76      4096.99   4052.98  ...   481.17           3.69
# 3   8392.25      4602.27   4559.20  ...   518.36           3.98
# 4   8768.30      4962.81   4918.27  ...   602.46           4.62
#
#    PublicAdminstration  Education  HealthService  OtherService   GDP2010  \
# ...

# %%
plt.plot(df['Year'], df['CrudeOil'])

# %%
df['Period'].unique()
# Out:
# array(['Annual', 'Q1', 'Q2', 'Q3', 'Q4'], dtype=object)

# %%
df2 = df[df['Period'] == 'Annual']

# %%
plt.style.use('ggplot')
plt.plot(df2['Year'],df2['CrudeOil'], ls = '--', lw=2.5, marker = 'o', mec = 'navy', mfc = 'navy')
plt.xlabel('YEAR')
plt.ylabel('GDP')
plt.title('TREND OF CRUDE OIL GDP IN MILLIONS')
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
figure = plt.figure(figsize = (10,10))
axes = figure.add_axes([0.1,0.1,0.8,0.7]) # left, bottom, width and height
axes.plot(df2['Year'],df2['CrudeOil'], ls = '--', lw=2.5, marker = 'o', mec = 'navy', mfc = 'navy')
axes.set_xlabel('Year')
axes.set_ylabel('GDP')
axes.set_title('TREND OF CRUDE OIL GDP IN MILLIONS')
plt.show()

# %%
figure = plt.figure(figsize = (10,10))
axes = figure.add_axes([0.1,0.1,0.8,0.7]) # left, bottom, width and height
axes.plot(df2['Year'],df2['CrudeOil'], ls = '--', lw=2.5, marker = 'o', mec = 'navy', mfc = 'navy' , markevery =3, label = 'CrdeOil')
axes.plot(df2['Year'],df2['Agriculture'], ls = '--', lw=2.5, marker = 'o', mec = 'navy', mfc = 'magenta', markevery =3, label = 'AGRIC')
axes.plot(df2['Year'],df2['Education'], ls = '--', lw=2.5, marker = 'o', mec = 'navy', mfc = 'green', markevery =3, label = 'ICT')
axes.plot(df2['Year'],df2['ICT'], ls = '--', lw=2.5, marker = 'o', mec = 'navy', mfc = 'blue', markevery =3, label = 'RealEstate')
axes.set_xlabel('Year')
axes.set_ylabel('GDP')
axes.set_title('TREND OF CRUDE OIL GDP IN MILLIONS')
plt.legend()
plt.show()

# %%
fig, axes = plt.subplots(2,3, figsize = (20,10))
axes[0,0].plot(df2['Year'],df2['CrudeOil'], ls = '--', lw=2.5, marker = 'o', mec = 'navy', mfc = 'navy' , markevery =3,)
axes[0,0].set_xlabel('YEAR', color = 'green', fontsize = 20)
axes[0,0].set_title('TREND OF CRUDE OIL OVER TIME', color = 'navy', fontsize = 20)
for label in axes[0,0].get_xticklabels():
    label.set_color('crimson')
for label in axes[0,0].get_yticklabels():
    label.set_color('crimson')

axes[0,1].bar(df2['Year'],df2['Agriculture'], color = 'magenta')
axes[0,1].set_xlabel('YEAR', color = 'brown', fontsize = 20)
axes[0,1].set_title('TREND OF AGRICULTURE OVER TIME', color = 'black', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'TREND OF AGRICULTURE OVER TIME')

# %%
df3 = df2[['Agriculture', 'CrudeOil', 'ICT', 'HealthService', 'Education', 'RealEstate']]
df3.loc['Total'] = (sum(df3['Agriculture']),sum(df3['CrudeOil']),sum(df3['ICT']),sum(df3['HealthService']),sum(df3['Education']),sum(df3['RealEstate']))
df3.tail()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10812\3227824487.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.loc['Total'] = (sum(df3['Agriculture']),sum(df3['CrudeOil']),sum(df3['ICT']),sum(df3['HealthService']),sum(df3['Education']),sum(df3['RealEstate']))
#        Agriculture   CrudeOil        ICT  HealthService  Education  RealEstate
# 78        17958.58    6270.86    9309.92         474.17    1519.66     4366.35
# 83        18348.18    5713.20   10537.14         484.74    1313.39     3963.59
# 88        18738.41    5239.05   11227.07         508.63    1303.55     4053.08
# 93        19091.07    4231.90   12323.04         529.99    1321.11     4213.07
# Total    366490.16  276493.28  132473.82       10462.17   27830.64   107536.58

# %%
fig,axes = plt.subplots(figsize = (6,6), dpi = 120)
axes.pie(df3.loc['Total'], labels=df3.columns,autopct='%1.2f%%', shadow = True, explode=[0.0,0.0,0.0,0.5,0.0,0.0])
plt.show()

# %%
fig, axes = plt.subplots(2,3, figsize = (20,15))
axes[0,0].plot(df2['Year'],df2['CrudeOil'], ls = '--', lw=2.5, marker = 'o', mec = 'navy', mfc = 'navy' , markevery =3,)
axes[0,0].set_xlabel('YEAR', color = 'green', fontsize = 20)
axes[0,0].set_title('TREND OF CRUDE OIL OVER TIME', color = 'navy', fontsize = 20)
for label in axes[0,0].get_xticklabels():
    label.set_color('crimson')
for label in axes[0,0].get_yticklabels():
    label.set_color('crimson')

axes[0,1].bar(df2['Year'],df2['Agriculture'], color = 'magenta')
axes[0,1].set_xlabel('YEAR', color = 'brown', fontsize = 20)
axes[0,1].set_title('TREND OF AGRICULTURE OVER TIME', color = 'black', fontsize = 20)

axes[0,2].bar(df2['Year'],df2['Fishing'], color = 'purple')
axes[0,2].set_xlabel('PERIOD', color = 'yellow', fontsize = 20)
axes[0,2].set_title('TREND OF FISHING OVER TIME', color = 'gold', fontsize = 20)

axes[1,0].step(df2['Year'],df2['Livestock'], color = 'green')
axes[1,0].set_xlabel('YEAR', color = 'blue', fontsize = 20)
axes[1,0].set_title('TREND OF LIVESTOCK OVER TIME', color = 'pink', fontsize = 20)

axes[1,1].plot(df2['Year'],df2['Fishing'], color = 'purple')
axes[1,1].set_xlabel('PERIOD', color = 'yellow', fontsize = 20)
axes[1,1].set_title('TREND OF FISHING OVER TIME', color = 'gold', fontsize = 20)


axes[1,2].fill_between(df2['Year'],df2['CropProduction'], color = 'black')
axes[1,2].set_xlabel('YEAR', color = 'red', fontsize = 20)
axes[1,2].set_title('TREND OF CROPPRODUCTION OVER TIME', color = 'navy', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'TREND OF CROPPRODUCTION OVER TIME')
