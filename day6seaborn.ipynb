# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.style.use('ggplot')
sns.displot(x=df['total_bill'],kde = True)

# %%
sns.regplot(x=df['total_bill'],y=df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.countplot(x=df['day'],color='navy')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
ax = sns.countplot(x = 'day', data=df, color='navy')

#Add counts on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'baseline', fontsize = 10, color = 'magenta', xytext=(0, 5),
                 textcoords='offset points')
    
plt.title('Day Distribution')
plt.xticks(rotation=45)
plt.legend(loc=[1,0])
plt.show
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,8))
ax = sns.countplot(x = 'day',hue = 'sex', data=df, palette='Blues',stat ='count')

#Add counts on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'baseline', fontsize = 10, color = 'magenta', xytext=(0, 5),
                 textcoords='offset points')
    
plt.title('Day Distribution')
plt.xticks(rotation=45)
plt.legend(loc=[1,0])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x = 'sex',y = 'total_bill', data=df, palette='Blues', estimator = 'sum')

#Add counts on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'baseline', fontsize = 10, color = 'magenta', xytext=(0, 5),
                 textcoords='offset points')
    
plt.title('Day Distribution')
plt.xticks(rotation=45)
plt.legend(loc=[1,0])
plt.show
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9404\35489701.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = 'sex',y = 'total_bill', data=df, palette='Blues', estimator = 'sum')
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x = 'sex',y = 'total_bill',hue = 'day', data=df, palette='Blues', estimator = 'max')

#Add counts on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'baseline', fontsize = 10, color = 'magenta', xytext=(0, 5),
                 textcoords='offset points')
    
plt.title('Day Distribution')
plt.xticks(rotation=45)
plt.legend(loc=[1,0])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,8))
ax = sns.violinplot(x = 'sex',y = 'total_bill', data=df, palette='Blues', hue = 'day')

# %%
plt.figure(figsize=(12,8))
ax = sns.swarmplot(x = 'sex',y = 'total_bill', data=df, palette='Blues', hue = 'day')

# %%
plt.figure(figsize=(12,8))
ax = sns.stripplot(x = 'sex',y = 'total_bill', data=df, palette='Blues', hue = 'day')

# %%
plt.figure(figsize=(12,8))
ax = sns.boxplot(x = 'sex',y = 'total_bill', data=df, palette='Blues', hue = 'day')

# %%
ax = sns.jointplot(x='total_bill',y='tip', data=df)

# %%
sns.pairplot(df)

# %%
df2 = df[['total_bill', 'tip','size']]
corr = df2.corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True, fmt = '0.3g')
# Out:
# <Axes: >

# %%
sns.clustermap(corr,annot=True, fmt = '0.3g')
