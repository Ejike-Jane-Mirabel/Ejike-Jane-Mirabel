# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df = pd.read_csv('mental_health_finaldata_1.csv')
df.head()
# Out:
#         Age  Gender Occupation        Days_Indoors Growing_Stress  \
# 0     20-25  Female  Corporate           1-14 days            Yes
# 1  30-Above    Male     Others          31-60 days            Yes
# 2  30-Above  Female    Student    Go out Every day             No
# 3     25-30    Male     Others           1-14 days            Yes
# 4     16-20  Female    Student  More than 2 months            Yes
#
#   Quarantine_Frustrations Changes_Habits Mental_Health_History Weight_Change  \
# 0                     Yes             No                   Yes           Yes
# 1                     Yes          Maybe                    No            No
# 2                      No            Yes                    No            No
# 3                      No          Maybe                    No         Maybe
# 4                     Yes            Yes                    No           Yes
#
#   Mood_Swings Coping_Struggles Work_Interest Social_Weakness
# ...

# %%
encoder = LabelEncoder()
category = df.select_dtypes(include=['object','category'])
for x in category:
    df[x] = encoder.fit_transform(df[x])
df.head()
# Out:
#    Age  Gender  Occupation  Days_Indoors  Growing_Stress  \
# 0    1       0           1             0               2
# 1    3       1           3             2               2
# 2    3       0           4             3               1
# 3    2       1           3             0               2
# 4    0       0           4             4               2
#
#    Quarantine_Frustrations  Changes_Habits  Mental_Health_History  \
# 0                        2               1                      2
# 1                        2               0                      1
# 2                        1               2                      1
# 3                        1               0                      1
# 4                        2               2                      1
#
#    Weight_Change  Mood_Swings  Coping_Struggles  Work_Interest  \
# 0              2            2                 0              1
# 1              1            0                 0              1
# ...

# %%
data = {'Age': ['20-25', '30-above', '30-above', '25-30', '16-20'],
        'Days_Indoors': ['1-14days', '31-60days', 'Go out Everyday', '1-14days', 'more than 2 months']
}
df = pd.read_csv('mental_health_finaldata_1.csv')
df.head()
sns.boxplot(x='Age', y='Days_Indoors', data=df, order =['20-25', '30-above', '25-30', '16-20'])
plt.xlabel('Age')
plt.ylabel('Days_Indoors')
plt.title('Box Plot: Age vs Days Indoors')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\USER\Documents\datascienceJane\project1.ipynb Cell 4 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> df = pd.read_csv('mental_health_finaldata_1.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> df.head()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> sns.boxplot(x='Age', y='Days_Indoors', data=df, order =['20-25', '30-above', '25-30', '16-20'])
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> plt.xlabel('Age')
# ...

# %%
encoder = LabelEncoder()
category = df.select_dtypes(include=['object','category'])
for x in category:
    df[x] = encoder.fit_transform(df[x])
df.head()
# Out:
#    Age  Gender  Occupation  Days_Indoors  Growing_Stress  \
# 0    1       0           1             0               2
# 1    3       1           3             2               2
# 2    3       0           4             3               1
# 3    2       1           3             0               2
# 4    0       0           4             4               2
#
#    Quarantine_Frustrations  Changes_Habits  Mental_Health_History  \
# 0                        2               1                      2
# 1                        2               0                      1
# 2                        1               2                      1
# 3                        1               0                      1
# 4                        2               2                      1
#
#    Weight_Change  Mood_Swings  Coping_Struggles  Work_Interest  \
# 0              2            2                 0              1
# 1              1            0                 0              1
# ...

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Days_Indoors', 'Growing_Stress',
#        'Quarantine_Frustrations', 'Changes_Habits', 'Mental_Health_History',
#        'Weight_Change', 'Mood_Swings', 'Coping_Struggles', 'Work_Interest',
#        'Social_Weakness'],
#       dtype='object')

# %%
genders = ['Male','Female']
Growing_Stress = ['Yes', 'No']

# %%
data = {'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
        'Growing_Stress': ['Yes', 'Yes', 'No', 'Yes', 'Yes']}

df = pd.read_csv('mental_health_finaldata_1.csv')
df.head()

sns.countplot(x='Growing_Stress', hue='Gender', data=df, order=['Yes', 'No'], palette='muted')
plt.xlabel('Growing_Stress')
plt.ylabel('Count')
plt.title('Gender-Based Differences in Growing Stress')

plt.show()

# %%
encoder = LabelEncoder()
category = df.select_dtypes(include=['object','category'])
for x in category:
    df[x] = encoder.fit_transform(df[x])
df.head()
# Out:
#    Age  Gender  Occupation  Days_Indoors  Growing_Stress  \
# 0    1       0           1             0               2
# 1    3       1           3             2               2
# 2    3       0           4             3               1
# 3    2       1           3             0               2
# 4    0       0           4             4               2
#
#    Quarantine_Frustrations  Changes_Habits  Mental_Health_History  \
# 0                        2               1                      2
# 1                        2               0                      1
# 2                        1               2                      1
# 3                        1               0                      1
# 4                        2               2                      1
#
#    Weight_Change  Mood_Swings  Coping_Struggles  Work_Interest  \
# 0              2            2                 0              1
# 1              1            0                 0              1
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Days_Indoors', 'Growing_Stress',
#        'Quarantine_Frustrations', 'Changes_Habits', 'Mental_Health_History',
#        'Weight_Change', 'Mood_Swings', 'Coping_Struggles', 'Work_Interest',
#        'Social_Weakness'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x =df['Age'], y=df['Quarantine_Frustrations'], color = 'navy')
plt.title('Predominant Frustrations By Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Mean Quarantine Frustration')
plt.grid(axis='y')
plt.show()

# %%
age_groups = df.groupby('Changes_Habits')['Mental_Health_History'].mean()

plt.figure(figsize=(10, 5))
sns.barplot(x =df['Age'], y=df['Quarantine_Frustrations'], color = 'green', )
plt.title('Changes in Habits vs Mental Health History')
plt.xlabel('Changes in Habits')
plt.ylabel('Mental Health History')
plt.grid(True)
plt.show()

# %%
sns.countplot(x=df['Quarantine_Frustrations'],color='navy')
# Out:
# <Axes: xlabel='Quarantine_Frustrations', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(x = 'Quarantine_Frustrations', data=df, color='navy')

#Add counts on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'baseline', fontsize = 10, color = 'magenta', xytext=(0, 5),
                 textcoords='offset points')
    
plt.title('Quarantine Fraustrations vs Weight Change')
plt.xticks(rotation=45)
plt.legend(loc=[1,0])
plt.show
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = {
    'Occupation': ['Corporate', 'Others', 'Students', 'Others', 'Students'],
    'MoodSwings': [2, 0, 2, 2, 2,]
}
df = pd.DataFrame()
sns.boxplot(x=df['Occupation'], y=df['MoodSwings'], color = 'navy')
plt.xlabel('Occupation')
plt.ylabel('MoodSwings')
plt.title('Distribution of MoodSwings Across Occupation')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\USER\Documents\datascienceJane\project1.ipynb Cell 14 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> data = {
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a>     'Occupation': ['Corporate', 'Others', 'Students', 'Others', 'Students'],
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a>     'MoodSwings': [2, 0, 2, 2, 2,]
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> }
# ...

# %%
gender = ['0', '1', '0', '1', '0']
Coping_Struggles = ['0', '0', '1', '0', '0']
sns.barplot(x =df['Gender'], y=df['Coping_Struggles'], color='magenta')
plt.title('Prevalence of Coping Struggles Across Genders')
plt.xlabel('Genders')
plt.ylabel('Coping Struggles(%)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\USER\Documents\datascienceJane\project1.ipynb Cell 15 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> gender = ['0', '1', '0', '1', '0']
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> Coping_Struggles = ['0', '0', '1', '0', '0']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> sns.barplot(x =df['Gender'], y=df['Coping_Struggles'], color='magenta')
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> plt.title('Prevalence of Coping Struggles Across Genders')
# ...

# %%
df = pd.read_csv('mental_health_finaldata_1.csv')
df.head()
# Out:
#         Age  Gender Occupation        Days_Indoors Growing_Stress  \
# 0     20-25  Female  Corporate           1-14 days            Yes
# 1  30-Above    Male     Others          31-60 days            Yes
# 2  30-Above  Female    Student    Go out Every day             No
# 3     25-30    Male     Others           1-14 days            Yes
# 4     16-20  Female    Student  More than 2 months            Yes
#
#   Quarantine_Frustrations Changes_Habits Mental_Health_History Weight_Change  \
# 0                     Yes             No                   Yes           Yes
# 1                     Yes          Maybe                    No            No
# 2                      No            Yes                    No            No
# 3                      No          Maybe                    No         Maybe
# 4                     Yes            Yes                    No           Yes
#
#   Mood_Swings Coping_Struggles Work_Interest Social_Weakness
# ...

# %%
encoder = LabelEncoder()
category = df.select_dtypes(include=['object','category'])
for x in category:
    df[x] = encoder.fit_transform(df[x])
df.head()
# Out:
#    Age  Gender  Occupation  Days_Indoors  Growing_Stress  \
# 0    1       0           1             0               2
# 1    3       1           3             2               2
# 2    3       0           4             3               1
# 3    2       1           3             0               2
# 4    0       0           4             4               2
#
#    Quarantine_Frustrations  Changes_Habits  Mental_Health_History  \
# 0                        2               1                      2
# 1                        2               0                      1
# 2                        1               2                      1
# 3                        1               0                      1
# 4                        2               2                      1
#
#    Weight_Change  Mood_Swings  Coping_Struggles  Work_Interest  \
# 0              2            2                 0              1
# 1              1            0                 0              1
# ...

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x =df['Work_Interest'], y=df['Mental Health History'], color='magenta')
plt.title('Work Interest vs Mental Health History during Quarantine')
plt.xlabel('Work Interest')
plt.ylabel('Count')
plt.grid(True)
plt.show
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\USER\Documents\datascienceJane\project1.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(8, 6))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> sns.barplot(x =df['Work_Interest'], y=df['Mental Health History'], color='magenta')
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> plt.title('Work Interest vs Mental Health History during Quarantine')
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/datascienceJane/project1.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> plt.xlabel('Work Interest')
#
# KeyError: 'Work_Interest'
